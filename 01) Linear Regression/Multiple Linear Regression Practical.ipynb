# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

import statsmodels.api as sm

# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'multiple_linear_regression_dataset.csv')
print(df.head())
type(df)
# Out:
#    Year        Date  Interest Rate  Unemployment Rate  Index Price
# 0  1990  12/31/1990            5.0                6.0         2000
# 1  1991  12/31/1991            5.2                6.2         2100
# 2  1992  12/31/1992            5.1                6.3         2200
# 3  1993  12/31/1993            5.3                6.1         2300
# 4  1994  12/31/1994            5.2                6.0         2400
# pandas.core.frame.DataFrame

# %%
df.drop(columns = ['Year', 'Date'], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Interest Rate      30 non-null     float64
#  1   Unemployment Rate  30 non-null     float64
#  2   Index Price        30 non-null     int64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.isnull().sum()
# Out:
# Interest Rate        0
# Unemployment Rate    0
# Index Price          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df)

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot = True, fmt = '.2f')
# Out:
# <Axes: >

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

print(f"X train size: {len(X_train)}")
print(f"X test size: {len(X_test)}")
# Out:
# X train size: 21
# X test size: 9

# %%
sns.regplot(x = 'Interest Rate', y = 'Index Price', data = df)
# Out:
# <Axes: xlabel='Interest Rate', ylabel='Index Price'>
