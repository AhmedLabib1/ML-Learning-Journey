# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **--------------------------- Loading and Preparing data ---------------------------**

# %%
from sklearn.datasets import load_iris

iris = load_iris()
X, y = load_iris(return_X_y = True)

# %% [markdown]
# ## **------------------------------ spliting data (manual) ------------------------------**

# %%
def my_train_test_split(X, y, test_size = 0.3):
    num_samples = X.shape[0]
    indices = np.arange(num_samples)
    np.random.shuffle(indices)
    split = int(num_samples * (1 - test_size))
    train_indices, test_indices = indices[:split], indices[split:]
    return X[train_indices], X[test_indices], y[train_indices], y[test_indices]

X_train, X_test, y_train, y_test = my_train_test_split(X, y, test_size=0.3)

# %% [markdown]
# ## **--------------------------- spliting data (Scikit Learn) ----------------------------**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# %% [markdown]
# ## **----------------------- Initializing Parameters (Scikit Learn) ----------------------**

# %%
w = np.zeros(X_train.shape[1]) # initialize weights
b = 0.0 # initialize bias
alpha = 0.001 # Learning Rate
n_iter = 100 # Number of Iteration

# %% [markdown]
# ## **----------------------- Initializing Parameters (Scikit Learn) ----------------------**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

# %% [markdown]
# ## **---------------------------- Gradient Descent (manual) ----------------------------**

# %%
# Gradient Descent
for i in range(n_iter):
    # Predictions (y_pred) for the current weights and bias
    y_pred = np.dot(X_train, w) + b # the equation is: y_pred = X_train * w + b

    # Calculate error
    error = y_pred - y_train  

    # Compute the loss Function (Mean Squared Error)
    loss = np.mean((y_pred - y_train) ** 2) 

    # Compute the gradients
    dj_dw = np.mean(error.reshape(-1, 1) * X_train, axis=0)  # Gradient for weights
    dj_db = np.mean(error)  # Gradient for bias
    
    # Update weights and bias
    w = w - alpha * dj_dw
    b = b - alpha * dj_db

    print(f"Iteration {i+1}: Weights = {w}, Bias = {b}")
# Out:
# Iteration 1: Weights = [0.08280656 0.01425    0.12595722 0.05238206], Bias = 0.008363893822892519
# Iteration 2: Weights = [0.08261957 0.01390847 0.12645089 0.05264365], Bias = 0.008284671777383873
# Iteration 3: Weights = [0.08243235 0.0135674  0.1269431  0.0529046 ], Bias = 0.00820551848740693
# Iteration 4: Weights = [0.08224494 0.01322682 0.12743388 0.0531649 ], Bias = 0.008126439975416282
# Iteration 5: Weights = [0.08205738 0.01288675 0.12792326 0.05342459], Bias = 0.00804744186672825
# Iteration 6: Weights = [0.08186971 0.01254718 0.12841125 0.05368365], Bias = 0.007968529414306768
# Iteration 7: Weights = [0.08168194 0.01220815 0.1288979  0.05394211], Bias = 0.00788970752200517
# Iteration 8: Weights = [0.08149412 0.01186967 0.12938321 0.05419996], Bias = 0.007810980766360088
# Iteration 9: Weights = [0.08130626 0.01153174 0.12986721 0.05445722], Bias = 0.007732353417027636
# Iteration 10: Weights = [0.0811184  0.01119438 0.13034991 0.05471389], Bias = 0.007653829455946461
# Iteration 11: Weights = [0.08093056 0.0108576  0.13083134 0.05496997], Bias = 0.007575412595306966
# Iteration 12: Weights = [0.08074275 0.01052141 0.13131152 0.05522549], Bias = 0.007497106294401084
# Iteration 13: Weights = [0.080555   0.01018582 0.13179046 0.05548043], Bias = 0.007418913775422324
# Iteration 14: Weights = [0.08036733 0.00985084 0.13226818 0.05573481], Bias = 0.007340838038281484
# Iteration 15: Weights = [0.08017976 0.00951647 0.13274469 0.05598863], Bias = 0.007262881874499353
# Iteration 16: Weights = [0.0799923  0.00918273 0.13322    0.05624189], Bias = 0.0071850478802338935
# Iteration 17: Weights = [0.07980498 0.00884962 0.13369413 0.05649461], Bias = 0.007107338468495823
# Iteration 18: Weights = [0.07961779 0.00851714 0.1341671  0.05674678], Bias = 0.007029755880603153
# Iteration 19: Weights = [0.07943077 0.00818531 0.13463891 0.05699841], Bias = 0.0069523021969220885
# Iteration 20: Weights = [0.07924391 0.00785412 0.13510957 0.05724951], Bias = 0.00687497934693875
# Iteration 21: Weights = [0.07905724 0.00752358 0.13557911 0.05750007], Bias = 0.0067977891187034
# Iteration 22: Weights = [0.07887076 0.00719371 0.13604751 0.05775011], Bias = 0.006720733167686258
# Iteration 23: Weights = [0.07868449 0.00686449 0.13651481 0.05799962], Bias = 0.00664381302508157
# Iteration 24: Weights = [0.07849843 0.00653594 0.136981   0.05824861], Bias = 0.006567030105594288
# Iteration 25: Weights = [0.07831259 0.00620806 0.1374461  0.05849708], Bias = 0.006490385714741605
# Iteration 26: Weights = [0.07812699 0.00588085 0.13791011 0.05874503], Bias = 0.006413881055699549
# Iteration 27: Weights = [0.07794163 0.00555431 0.13837304 0.05899248], Bias = 0.006337517235722995
# Iteration 28: Weights = [0.07775651 0.00522845 0.13883489 0.05923941], Bias = 0.006261295272165655
# Iteration 29: Weights = [0.07757165 0.00490328 0.13929569 0.05948584], Bias = 0.006185216098124964
# Iteration 30: Weights = [0.07738705 0.00457878 0.13975543 0.05973176], Bias = 0.006109280567735247
# Iteration 31: Weights = [0.07720272 0.00425496 0.14021412 0.05997718], Bias = 0.006033489461131044
# Iteration 32: Weights = [0.07701866 0.00393184 0.14067176 0.06022211], Bias = 0.0059578434891011806
# Iteration 33: Weights = [0.07683488 0.00360939 0.14112837 0.06046653], Bias = 0.005882343297452806
# Iteration 34: Weights = [0.07665138 0.00328764 0.14158394 0.06071046], Bias = 0.005806989471103507
# Iteration 35: Weights = [0.07646816 0.00296658 0.14203849 0.0609539 ], Bias = 0.005731782537918402
# Iteration 36: Weights = [0.07628524 0.0026462  0.14249202 0.06119685], Bias = 0.005656722972308125
# Iteration 37: Weights = [0.07610261 0.00232652 0.14294453 0.06143931], Bias = 0.005581811198602584
# Iteration 38: Weights = [0.07592028 0.00200753 0.14339603 0.06168129], Bias = 0.005507047594214463
# Iteration 39: Weights = [0.07573825 0.00168923 0.14384652 0.06192278], Bias = 0.005432432492605568
# Iteration 40: Weights = [0.07555653 0.00137162 0.14429602 0.06216378], Bias = 0.005357966186068296
# Iteration 41: Weights = [0.07537511 0.0010547  0.14474451 0.06240431], Bias = 0.00528364892833374
# Iteration 42: Weights = [0.075194   0.00073848 0.14519202 0.06264436], Bias = 0.005209480937017246
# Iteration 43: Weights = [0.07501321 0.00042295 0.14563853 0.06288393], Bias = 0.005135462395911522
# Iteration 44: Weights = [7.48327249e-02 1.08111426e-04 1.46084064e-01 6.31230264e-02], Bias = 0.005061593457136821
# Iteration 45: Weights = [ 0.07465256 -0.00020603  0.14652861  0.06336165], Bias = 0.004987874243157083
# Iteration 46: Weights = [ 0.07447271 -0.00051949  0.14697219  0.0635998 ], Bias = 0.004914304848670395
# Iteration 47: Weights = [ 0.07429319 -0.00083225  0.14741479  0.06383748], Bias = 0.004840885342381599
# Iteration 48: Weights = [ 0.07411398 -0.00114431  0.14785642  0.06407468], Bias = 0.004767615768664385
# Iteration 49: Weights = [ 0.0739351  -0.00145569  0.14829709  0.06431143], Bias = 0.004694496149119754
# Iteration 50: Weights = [ 0.07375654 -0.00176638  0.14873679  0.0645477 ], Bias = 0.004621526484037311
# Iteration 51: Weights = [ 0.0735783  -0.00207637  0.14917553  0.06478351], Bias = 0.0045487067537654385
# Iteration 52: Weights = [ 0.07340039 -0.00238568  0.14961332  0.06501885], Bias = 0.004476036919996022
# Iteration 53: Weights = [ 0.07322281 -0.0026943   0.15005015  0.06525374], Bias = 0.004403516926969063
# Iteration 54: Weights = [ 0.07304556 -0.00300222  0.15048604  0.06548816], Bias = 0.004331146702602155
# Iteration 55: Weights = [ 0.07286863 -0.00330947  0.15092097  0.06572212], Bias = 0.004258926159549516
# Iteration 56: Weights = [ 0.07269203 -0.00361602  0.15135497  0.06595563], Bias = 0.004186855196194954
# Iteration 57: Weights = [ 0.07251577 -0.00392189  0.15178802  0.06618867], Bias = 0.004114933697582898
# Iteration 58: Weights = [ 0.07233983 -0.00422707  0.15222013  0.06642126], Bias = 0.00404316153629133
# Iteration 59: Weights = [ 0.07216422 -0.00453157  0.15265131  0.0666534 ], Bias = 0.003971538573250259
# Iteration 60: Weights = [ 0.07198894 -0.00483539  0.15308155  0.06688508], Bias = 0.0039000646585091174
# Iteration 61: Weights = [ 0.071814   -0.00513852  0.15351086  0.06711631], Bias = 0.0038287396319562623
# Iteration 62: Weights = [ 0.07163938 -0.00544098  0.15393925  0.06734709], Bias = 0.0037575633239935726
# Iteration 63: Weights = [ 0.0714651  -0.00574275  0.15436671  0.06757741], Bias = 0.00368653555616893
# Iteration 64: Weights = [ 0.07129115 -0.00604384  0.15479325  0.06780729], Bias = 0.0036156561417692136
# Iteration 65: Weights = [ 0.07111753 -0.00634426  0.15521886  0.06803672], Bias = 0.003544924886376269
# Iteration 66: Weights = [ 0.07094424 -0.006644    0.15564356  0.06826571], Bias = 0.0034743415883881517
# Iteration 67: Weights = [ 0.07077128 -0.00694306  0.15606734  0.06849425], Bias = 0.003403906039507817
# Iteration 68: Weights = [ 0.07059865 -0.00724145  0.15649021  0.06872234], Bias = 0.003333618025201277
# Iteration 69: Weights = [ 0.07042635 -0.00753917  0.15691217  0.06894999], Bias = 0.0032634773251271286
# Iteration 70: Weights = [ 0.07025438 -0.00783621  0.15733322  0.0691772 ], Bias = 0.003193483713539243
# Iteration 71: Weights = [ 0.07008275 -0.00813258  0.15775337  0.06940396], Bias = 0.0031236369596642772
# Iteration 72: Weights = [ 0.06991144 -0.00842828  0.15817261  0.06963029], Bias = 0.003053936828055585
# Iteration 73: Weights = [ 0.06974047 -0.00872332  0.15859095  0.06985617], Bias = 0.0029843830789249943
# Iteration 74: Weights = [ 0.06956982 -0.00901768  0.15900838  0.07008162], Bias = 0.002914975468453829
# Iteration 75: Weights = [ 0.0693995  -0.00931138  0.15942492  0.07030663], Bias = 0.0028457137490844713
# Iteration 76: Weights = [ 0.06922952 -0.00960442  0.15984057  0.07053121], Bias = 0.0027765976697936754
# Iteration 77: Weights = [ 0.06905986 -0.00989679  0.16025532  0.07075535], Bias = 0.0027076269763487678
# Iteration 78: Weights = [ 0.06889053 -0.0101885   0.16066918  0.07097905], Bias = 0.0026388014115478033
# Iteration 79: Weights = [ 0.06872153 -0.01047954  0.16108216  0.07120232], Bias = 0.002570120715444674
# Iteration 80: Weights = [ 0.06855285 -0.01076993  0.16149424  0.07142516], Bias = 0.0025015846255601114
# Iteration 81: Weights = [ 0.0683845  -0.01105966  0.16190544  0.07164757], Bias = 0.002433192877079458
# Iteration 82: Weights = [ 0.06821648 -0.01134873  0.16231576  0.07186954], Bias = 0.0023649452030380337
# Iteration 83: Weights = [ 0.06804879 -0.01163714  0.1627252   0.07209109], Bias = 0.0022968413344948706
# Iteration 84: Weights = [ 0.06788142 -0.01192491  0.16313376  0.07231221], Bias = 0.0022288810006955394
# Iteration 85: Weights = [ 0.06771437 -0.01221201  0.16354144  0.0725329 ], Bias = 0.002161063929224749
# Iteration 86: Weights = [ 0.06754765 -0.01249847  0.16394825  0.07275317], Bias = 0.002093389846149356
# Iteration 87: Weights = [ 0.06738126 -0.01278427  0.16435418  0.07297301], Bias = 0.002025858476152379
# Iteration 88: Weights = [ 0.06721519 -0.01306942  0.16475925  0.07319242], Bias = 0.0019584695426585834
# Iteration 89: Weights = [ 0.06704944 -0.01335393  0.16516344  0.07341141], Bias = 0.0018912227679521566
# Iteration 90: Weights = [ 0.06688401 -0.01363779  0.16556677  0.07362998], Bias = 0.0018241178732869715
# Iteration 91: Weights = [ 0.06671891 -0.013921    0.16596923  0.07384813], Bias = 0.0017571545789898946
# Iteration 92: Weights = [ 0.06655413 -0.01420357  0.16637083  0.07406585], Bias = 0.0016903326045575777
# Iteration 93: Weights = [ 0.06638967 -0.0144855   0.16677157  0.07428316], Bias = 0.001623651668747136
# Iteration 94: Weights = [ 0.06622553 -0.01476678  0.16717145  0.07450004], Bias = 0.001557111489661094
# Iteration 95: Weights = [ 0.0660617  -0.01504742  0.16757048  0.07471651], Bias = 0.001490711784826957
# Iteration 96: Weights = [ 0.0658982  -0.01532743  0.16796865  0.07493256], Bias = 0.0014244522712717434
# Iteration 97: Weights = [ 0.06573502 -0.01560679  0.16836596  0.0751482 ], Bias = 0.0013583326655917918
# Iteration 98: Weights = [ 0.06557215 -0.01588553  0.16876243  0.07536342], Bias = 0.0012923526840181358
# Iteration 99: Weights = [ 0.06540961 -0.01616362  0.16915804  0.07557822], Bias = 0.0012265120424777257
# Iteration 100: Weights = [ 0.06524737 -0.01644108  0.16955281  0.07579261], Bias = 0.0011608104566507528

# %% [markdown]
# ## **-------------------------- Gradient Descent (Scikit Learn) -------------------------**

# %%
# Train the model

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## **-------------------------- Making Predictions (manual) ---------------------------**

# %%
y_pred_test = np.dot(X_test, w) + b
y_pred_test
# Out:
# array([1.43740848, 1.04167642, 1.29411883, 1.15469752, 1.20857143,
#        0.61873063, 1.2598927 , 1.01625648, 0.68969728, 0.75475067,
#        1.52779731, 0.63144579, 0.66320938, 0.63406451, 1.24953483,
#        1.38055247, 0.76587591, 1.03401467, 0.6229775 , 0.69832175,
#        0.67406373, 1.18915962, 0.63108241, 0.71920791, 1.1185181 ,
#        0.65636925, 1.63318452, 1.31927586, 0.59421117, 1.17256096,
#        1.39249695, 1.27758479, 1.47959364, 1.14314189, 0.91627568,
#        1.26808678, 1.42247381, 1.29872999, 1.41606646, 1.62046936,
#        1.3281967 , 1.09571689, 1.46252636, 1.37002087, 0.59383264])

# %% [markdown]
# ## **------------------------ Making Predictions (Sckit Learn) -------------------------**

# %%
y_pred_test = lr.predict(X_test)
y_pred_test
# Out:
# array([ 2.05242562e+00,  1.23127925e+00,  1.65515468e+00,  1.25026686e+00,
#         1.28503661e+00, -4.60352823e-02,  1.56117743e+00,  9.02484963e-01,
#        -6.02980210e-02,  1.93461233e-03,  1.77844458e+00, -9.64269551e-02,
#         1.19595831e-02,  1.34720183e-02,  1.79130712e+00,  1.89667577e+00,
#        -1.39905944e-02,  9.86736785e-01, -9.75657939e-03, -2.26601405e-02,
#        -1.08124666e-02,  1.11517728e+00, -1.07508077e-01,  1.80466716e-01,
#         1.17967495e+00,  2.50096883e-02,  1.94331355e+00,  1.31632844e+00,
#         3.56514421e-02,  1.14037137e+00,  1.90714708e+00,  1.29415922e+00,
#         2.05075644e+00,  1.41010445e+00,  8.83340611e-01,  1.74272769e+00,
#         1.73364959e+00,  1.19625098e+00,  1.83398336e+00,  1.99370522e+00,
#         1.52004095e+00,  9.60779630e-01,  2.25901671e+00,  1.73848669e+00,
#        -8.24414423e-03])

# %% [markdown]
# # **------------------ Evaluating the Model (manual) ------------------**

# %%
mse = np.mean((y_test - y_pred_test) ** 2)
print("Mean Squared Error:", mse)
print("Model Coefficients:", w)
print("Model Intercept:", b)
# Out:
# Mean Squared Error: 0.03790384760872872
# Model Coefficients: [0.08299329 0.01459198 0.12546206 0.05211981]
# Model Intercept: 0.008443178177907452

# %% [markdown]
# ## **----------------------- Evaluating the Model (Scikit Learn) -----------------------**

# %%
from sklearn.metrics import mean_squared_error

# Compute Mean Squared Error
mse = mean_squared_error(y_test, y_pred_test)
print("Mean Squared Error:", mse)
print("Model Coefficients:", lr.coef_)
print("Model Intercept:", lr.intercept_)
# Out:
# Mean Squared Error: 0.03790384760872872
# Model Coefficients: [-0.12597046  0.00453059  0.23681657  0.60570165]
# Model Intercept: 0.10252611594425542
